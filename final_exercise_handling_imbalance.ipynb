# %% [markdown]
# <a href="https://colab.research.google.com/github/babatundeibukun/DEEP-LEARNING-PROJECT---COMPUTER/blob/main/final_exercise_handling_imbalance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #Load the dataset

# %%
df = pd.read_csv('/content/customer_churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# #Dataset examination

# %%
df.shape
# Out:
# (7043, 21)

# %%
for cols in df:
  print(f'{cols} : {df[cols].unique()}')
# Out:
# customerID : ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
# gender : ['Female' 'Male']
# SeniorCitizen : [0 1]
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# tenure : [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26  0
#  39]
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No phone service' 'No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes' 'No internet service']
# OnlineBackup : ['Yes' 'No' 'No internet service']
# DeviceProtection : ['No' 'Yes' 'No internet service']
# TechSupport : ['No' 'Yes' 'No internet service']
# StreamingTV : ['No' 'Yes' 'No internet service']
# StreamingMovies : ['No' 'Yes' 'No internet service']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# ...

# %% [markdown]
# #As seen above , many of the the columns are categorical columns , lets handle that

# %%
#lets zoom in on the categorical columns first
def all_columns_unique_values():
  for cols in df:
    if df[cols].dtypes == 'object' :
      print(f'{cols} : {df[cols].unique()}')

all_columns_unique_values()
# Out:
# customerID : ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
# gender : ['Female' 'Male']
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No phone service' 'No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes' 'No internet service']
# OnlineBackup : ['Yes' 'No' 'No internet service']
# DeviceProtection : ['No' 'Yes' 'No internet service']
# TechSupport : ['No' 'Yes' 'No internet service']
# StreamingTV : ['No' 'Yes' 'No internet service']
# StreamingMovies : ['No' 'Yes' 'No internet service']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# TotalCharges : ['29.85' '1889.5' '108.15' ... '346.45' '306.6' '6844.5']
# Churn : ['No' 'Yes']

# %%
#we need to do some columns as they are not neccesary
df = df.drop('customerID', axis = 1, )

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# #Data cleaning continues

# %%
#columns like this MultipleLines, OnlineSecurity ,  OnlineBackup , DeviceProtection , TechSupport , StreamingTV , StreamingMovies

# %%
cols = ['MultipleLines', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']

# %%
df[cols] = df[cols].replace({'No internet service' : 'No', 'No phone service' : 'No'})

# %%
all_columns_unique_values()
# Out:
# gender : ['Female' 'Male']
# Partner : ['Yes' 'No']
# Dependents : ['No' 'Yes']
# PhoneService : ['No' 'Yes']
# MultipleLines : ['No' 'Yes']
# InternetService : ['DSL' 'Fiber optic' 'No']
# OnlineSecurity : ['No' 'Yes']
# OnlineBackup : ['Yes' 'No']
# DeviceProtection : ['No' 'Yes']
# TechSupport : ['No' 'Yes']
# StreamingTV : ['No' 'Yes']
# StreamingMovies : ['No' 'Yes']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling : ['Yes' 'No']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# TotalCharges : ['29.85' '1889.5' '108.15' ... '346.45' '306.6' '6844.5']
# Churn : ['No' 'Yes']

# %%
#for whatever reason , we can see that we have several categorical variables , we can replace , we need to handle that

# %%
cols_with_yes_no = ['Partner', 'Dependents', 'PhoneService', 'MultipleLines','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'Churn', 'gender']
df[cols_with_yes_no] = df[cols_with_yes_no].replace({'Yes': 1, 'No' : 0, 'Female':0, 'Male' : 1})
df[cols_with_yes_no].head()
# Out:
# <ipython-input-74-7b6f237aec7f>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[cols_with_yes_no] = df[cols_with_yes_no].replace({'Yes': 1, 'No' : 0, 'Female':0, 'Male' : 1})
#    Partner  Dependents  PhoneService  MultipleLines  OnlineSecurity  \
# 0        1           0             0              0               0
# 1        0           0             1              0               1
# 2        0           0             1              0               1
# 3        0           0             0              0               1
# 4        0           0             1              0               0
#
#    OnlineBackup  DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# ...

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# 0              0             DSL               0             1
# 1              0             DSL               1             0
# 2              0             DSL               1             1
# 3              0             DSL               1             0
# 4              0     Fiber optic               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0                 0            0            0                0
# ...

# %% [markdown]
# #We are getting there but not quite there yet

# %%
all_columns_unique_values()
# Out:
# InternetService : ['DSL' 'Fiber optic' 'No']
# Contract : ['Month-to-month' 'One year' 'Two year']
# PaymentMethod : ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# TotalCharges : ['29.85' '1889.5' '108.15' ... '346.45' '306.6' '6844.5']

# %% [markdown]
# #from the above , we are are closer but some columns are still categorical , we need to fix that !

# %%
df.isna().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# We can use one hot encoding to fix these ones, don't you think so ?
#let me show you .

df = pd.get_dummies(df, columns =['InternetService','Contract', 'PaymentMethod'], drop_first= True, dtype = int)
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 0              0               0             1                 0  ...
# 1              0               1             0                 1  ...
# 2              0               1             1                 0  ...
# 3              0               1             0                 1  ...
# 4              0               0             0                 0  ...
#
#    MonthlyCharges  TotalCharges  Churn  InternetService_Fiber optic  \
# ...

# %%
all_columns_unique_values()
# Out:
# TotalCharges : ['29.85' '1889.5' '108.15' ... '346.45' '306.6' '6844.5']

# %%
#We are almost there , but it seems the totalcharges column is coming off like it is an object columns , lets examine it

# %%
df['TotalCharges'].isna().any()
# Out:
# False

# %%
df['TotalCharges'].value_counts()
# Out:
# TotalCharges
#           11
# 20.2      11
# 19.75      9
# 20.05      8
# 19.9       8
#           ..
# 6849.4     1
# 692.35     1
# 130.15     1
# 3211.9     1
# 6844.5     1
# Name: count, Length: 6531, dtype: int64

# %%
df['TotalCharges']=pd.to_numeric(df.TotalCharges)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string " "
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-141-b7d9dbbf8e0b> in <cell line: 1>()
# ----> 1 df['TotalCharges']=pd.to_numeric(df.TotalCharges)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast, dtype_backend)
#     230         coerce_numeric = errors not in ("ignore", "raise")
#     231         try:
# --> 232             values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]
#     233                 values,
#     234                 set(),
#
# lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ...

# %%
#the error above gave it away that there is an NaN in ourr dataset

# %%
#Lets find where the NaN are in our dataset and deal with them
df[df['TotalCharges'] == " "]
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 488        0              0        1           1       0             0
# 753        1              0        0           1       0             1
# 936        0              0        1           1       0             1
# 1082       1              0        1           1       0             1
# 1340       0              0        1           1       0             0
# 3331       1              0        1           1       0             1
# 3826       1              0        1           1       0             1
# 4380       0              0        1           1       0             1
# 5218       1              0        1           1       0             1
# 6670       0              0        1           1       0             1
# 6754       1              0        0           1       0             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# ...

# %%
df[df['TotalCharges'] == " "].shape
# Out:
# (11, 24)

# %% [markdown]
# We can drop those 24 columns from our dataset

# %%
all_columns_unique_values()
# Out:
# TotalCharges : ['29.85' '1889.5' '108.15' ... '346.45' '306.6' '6844.5']

# %%
df.dtypes
# Out:
# gender                                     int64
# SeniorCitizen                              int64
# Partner                                    int64
# Dependents                                 int64
# tenure                                     int64
# PhoneService                               int64
# MultipleLines                              int64
# OnlineSecurity                             int64
# OnlineBackup                               int64
# DeviceProtection                           int64
# TechSupport                                int64
# StreamingTV                                int64
# StreamingMovies                            int64
# PaperlessBilling                           int64
# MonthlyCharges                           float64
# TotalCharges                             float64
# Churn                                      int64
# InternetService_Fiber optic                int64
# InternetService_No                         int64
# ...

# %%
df1 = df[df['TotalCharges'] != " "]
df1.shape
# Out:
# (7032, 24)

# %%
df1.dtypes
# Out:
# gender                                     int64
# SeniorCitizen                              int64
# Partner                                    int64
# Dependents                                 int64
# tenure                                     int64
# PhoneService                               int64
# MultipleLines                              int64
# OnlineSecurity                             int64
# OnlineBackup                               int64
# DeviceProtection                           int64
# TechSupport                                int64
# StreamingTV                                int64
# StreamingMovies                            int64
# PaperlessBilling                           int64
# MonthlyCharges                           float64
# TotalCharges                              object
# Churn                                      int64
# InternetService_Fiber optic                int64
# InternetService_No                         int64
# ...

# %% [markdown]
# #We have removed the NaN , Now we can convert it to numeric

# %%
df1['TotalCharges'] = pd.to_numeric(df1['TotalCharges'])
# Out:
# <ipython-input-148-cffe5c08e1e6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['TotalCharges'] = pd.to_numeric(df1['TotalCharges'])

# %%
df1.dtypes
# Out:
# gender                                     int64
# SeniorCitizen                              int64
# Partner                                    int64
# Dependents                                 int64
# tenure                                     int64
# PhoneService                               int64
# MultipleLines                              int64
# OnlineSecurity                             int64
# OnlineBackup                               int64
# DeviceProtection                           int64
# TechSupport                                int64
# StreamingTV                                int64
# StreamingMovies                            int64
# PaperlessBilling                           int64
# MonthlyCharges                           float64
# TotalCharges                             float64
# Churn                                      int64
# InternetService_Fiber optic                int64
# InternetService_No                         int64
# ...

# %%
def columns_unique_value(df):
  for cols in df:
    print(f'{cols}: {df[cols].unique()}')

# %%
columns_unique_value(df1)
# Out:
# gender: [0 1]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# OnlineBackup: [1 0]
# DeviceProtection: [0 1]
# TechSupport: [0 1]
# StreamingTV: [0 1]
# StreamingMovies: [0 1]
# PaperlessBilling: [1 0]
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# Churn: [0 1]
# InternetService_Fiber optic: [0 1]
# InternetService_No: [0 1]
# Contract_One year: [0 1]
# Contract_Two year: [0 1]
# PaymentMethod_Credit card (automatic): [0 1]
# PaymentMethod_Electronic check: [1 0]
# PaymentMethod_Mailed check: [0 1]

# %% [markdown]
# #I need to scale some columns , you see!

# %%
from sklearn.preprocessing import MinMaxScaler
sx = MinMaxScaler()

# %%
cols_to_scale = ['tenure', 'MonthlyCharges', 'TotalCharges']

df1[cols_to_scale] = sx.fit_transform(df1[cols_to_scale])
df1[cols_to_scale].head()
# Out:
# <ipython-input-153-5e6e3e290c34>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[cols_to_scale] = sx.fit_transform(df1[cols_to_scale])
#      tenure  MonthlyCharges  TotalCharges
# 0  0.000000        0.115423      0.001275
# 1  0.464789        0.385075      0.215867
# 2  0.014085        0.354229      0.010310
# 3  0.619718        0.239303      0.210241
# 4  0.014085        0.521891      0.015330

# %%
columns_unique_value(df1)
# Out:
# gender: [0 1]
# SeniorCitizen: [0 1]
# Partner: [1 0]
# Dependents: [0 1]
# tenure: [0.         0.46478873 0.01408451 0.61971831 0.09859155 0.29577465
#  0.12676056 0.38028169 0.85915493 0.16901408 0.21126761 0.8028169
#  0.67605634 0.33802817 0.95774648 0.71830986 0.98591549 0.28169014
#  0.15492958 0.4084507  0.64788732 1.         0.22535211 0.36619718
#  0.05633803 0.63380282 0.14084507 0.97183099 0.87323944 0.5915493
#  0.1971831  0.83098592 0.23943662 0.91549296 0.11267606 0.02816901
#  0.42253521 0.69014085 0.88732394 0.77464789 0.08450704 0.57746479
#  0.47887324 0.66197183 0.3943662  0.90140845 0.52112676 0.94366197
#  0.43661972 0.76056338 0.50704225 0.49295775 0.56338028 0.07042254
#  0.04225352 0.45070423 0.92957746 0.30985915 0.78873239 0.84507042
#  0.18309859 0.26760563 0.73239437 0.54929577 0.81690141 0.32394366
#  0.6056338  0.25352113 0.74647887 0.70422535 0.35211268 0.53521127]
# PhoneService: [0 1]
# MultipleLines: [0 1]
# OnlineSecurity: [0 1]
# ...

# %% [markdown]
# #We need to split the dataset into train and test

# %%
X = df1.drop('Churn', axis = 1)
X.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 0       0              0        1           0  0.000000             0
# 1       1              0        0           0  0.464789             1
# 2       1              0        0           0  0.014085             1
# 3       1              0        0           0  0.619718             0
# 4       0              0        0           0  0.014085             1
#
#    MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# 0              0               0             1                 0  ...
# 1              0               1             0                 1  ...
# 2              0               1             1                 0  ...
# 3              0               1             0                 1  ...
# 4              0               0             0                 0  ...
#
#    PaperlessBilling  MonthlyCharges  TotalCharges  \
# 0                 1        0.115423      0.001275
# ...

# %%
X.shape
# Out:
# (7032, 23)

# %%
y = df1['Churn']
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Churn, dtype: int64

# %% [markdown]
# #Building a logistic regression model

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 234, stratify = y)

# %%
y.value_counts()
# Out:
# Churn
# 0    5163
# 1    1869
# Name: count, dtype: int64

# %%
X_train.shape
# Out:
# (5625, 23)

# %% [markdown]
# #We have an imbalance dataset

# %%
#we cant just throw all of this into our model
##Lets solve the problem of imbalance

# %% [markdown]
# #Method 1 : oversampling the minority class

# %%
#Make a train set into a dataframe for easy manipulation

# %%
df2 = X_train
df2['churn'] = y_train

# %%
df2.shape
# Out:
# (5625, 24)

# %%
class_0 = df2[df2['churn']== 0]

# %%
class_1 = df2[df2['churn']== 1]

# %%
count_0, count_1 = class_0[0], class_1[0]
count_0, count_1
# Out:
# (4130, 1495)

# %% [markdown]
# #Lets oversample the minority class

# %%
df_over_sample =  class_1.sample(count_0, replace= True)
df_over_sample.shape
# Out:
# (4130, 24)

# %%
df_train = pd.concat([df_over_sample, class_0],  axis = 0)
df_train.shape
# Out:
# (8260, 24)

# %%
df_train['churn'].value_counts()
# Out:
# churn
# 1    4130
# 0    4130
# Name: count, dtype: int64

# %% [markdown]
# #Now we have balanced dataset

# %%
X_train = df_train.drop('churn', axis = 1)
X_train
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 4800       1              1        0           0  0.000000             1
# 2424       0              0        0           0  0.788732             1
# 134        1              0        0           0  0.014085             1
# 1578       0              0        0           0  0.084507             1
# 1880       1              0        0           0  0.014085             1
# ...      ...            ...      ...         ...       ...           ...
# 4716       0              0        1           0  0.915493             1
# 2814       0              0        1           1  0.859155             0
# 6728       0              0        1           0  1.000000             1
# 578        1              1        1           0  0.478873             1
# 2787       1              0        1           1  1.000000             1
#
#       MultipleLines  OnlineSecurity  OnlineBackup  DeviceProtection  ...  \
# ...

# %%
y_train = df_train['churn']
y_train.head()
# Out:
# 4800    1
# 2424    1
# 134     1
# 1578    1
# 1880    1
#        ..
# 4716    0
# 2814    0
# 6728    0
# 578     0
# 2787    0
# Name: churn, Length: 8260, dtype: int64

# %% [markdown]
# #lets throw the x_train and y_train

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = np.round(model.predict(X_test))
y_pred
# Out:
# array([1, 0, 0, ..., 0, 1, 0])

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.72      0.81      1033
#            1       0.52      0.82      0.63       374
#
#     accuracy                           0.75      1407
#    macro avg       0.72      0.77      0.72      1407
# weighted avg       0.81      0.75      0.76      1407

# %% [markdown]
# #Method 2 undersampling the majority class

# %%
df_under_sample = class_0.sample(count_1)
df_under_sample.shape
# Out:
# (1495, 24)

# %%
df_train_1 = pd.conca
